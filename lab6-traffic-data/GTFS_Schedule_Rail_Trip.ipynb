# %% [markdown]
# ### Explore the GTFS data in Philadelphia
#
# The General Transit Feed Specification (GTFS) is an Open Standard used to distribute relevant information about transit systems to riders. The GTFS data of Philadelphia can be downloaded from, https://transitfeeds.com/p/septa, for both bus and regional rail datasets.
#
# The tutorial was developed based on https://medium.com/@sureshd_731/working-with-gtfs-how-to-find-schedule-for-a-bus-5bd95fdf646a. The goal of this example is to extract route details, stops, and schedule information for one trip of a particular route.
#
# Last modified by Xiaojiang li, Temple University, Dec 2, 2023

# %%
import pandas as pd

# %% [markdown]
# #### bus and rail data folders in Philadelphia

# %%
bus_dir_path="gtfs_bus"
rail_dir_path = "gtfs_rail"

# %% [markdown]
# #### Check the route for bus

# %%
routes_file = bus_dir_path+"/routes.txt"
df = pd.read_csv(routes_file)

df
# Out:
#     route_id route_short_name                     route_long_name  route_type  \
# 0          1                1            Parx Casino to 54th-City           3
# 1         10               10         13th-Market to 63rd-Malvern           0
# 2        101              101                 Media to 69th St TC           0
# 3        102              102           Sharon Hill to 69th St TC           0
# 4        103              103               Ardmore to 69th St TC           3
# ..       ...              ...                                 ...         ...
# 161      MFL              MFL          Frankford TC to 69th St TC           1
# 162      MFO              MFO  Midnight-5am Service (Bus) for MFL           3
# 163     NHSL             NHSL         Norristown TC to 69th St TC           0
# 164        R                R  Henry-Mid or WissTC to FrankfordTC           3
# 165       XH               XH  Broad-Erie to Cheltenham-Ogontz-XH           3
#
#     route_color route_text_color  route_url
# 0           NaN              NaN        NaN
# 1        66CC33           000000        NaN
# 2        66CC33           000000        NaN
# 3        66CC33           000000        NaN
# 4           NaN              NaN        NaN
# ..          ...              ...        ...
# 161      0000DF           FFFFFF        NaN
# 162         NaN              NaN        NaN
# 163      A033B3           FFFFFF        NaN
# 164         NaN              NaN        NaN
# 165         NaN              NaN        NaN
#
# [166 rows x 7 columns]

# %% [markdown]
# #### Let's load the trips.txt file.

# %%
trips_file = bus_dir_path + "/trips.txt"
bus_trips = pd.read_csv(trips_file)

print(bus_trips.shape)
bus_trips
# Out:
# (49321, 7)
#       route_id  service_id  trip_id                     trip_headsign  \
# 0            1          10    87152                  Decatur-Drummond
# 1            1          10    87153                       Parx Casino
# 2            1          10    87154  Parx Casino via Decatur-Drummond
# 3            1          10    87155                  Decatur-Drummond
# 4            1          10    87156  Parx Casino via Decatur-Drummond
# ...        ...         ...      ...                               ...
# 49316       15          55    36251             Richmond-Westmoreland
# 49317       15          55    36252             Richmond-Westmoreland
# 49318       15          55    36253             Richmond-Westmoreland
# 49319       15          55    36254             Richmond-Westmoreland
# 49320       15          55    36255             Richmond-Westmoreland
#
#        block_id  direction_id  shape_id
# 0          1003             0    275147
# 1          2151             0    275145
# 2          2155             0    275152
# 3          1426             0    275151
# 4          2153             0    275152
# ...         ...           ...       ...
# 49316      9007             1    274394
# 49317      9009             1    274394
# 49318      9008             1    274394
# 49319      9003             1    274394
# 49320      9004             1    274394
#
# [49321 rows x 7 columns]

# %% [markdown]
# ##### Get the trips for number 10, use '10' not 10 here

# %%
selected_trip = bus_trips[(bus_trips['route_id'] == '10') & (bus_trips['direction_id'] == 0) ] #& (bus_trips['trip_headsign'] == 'Temple University')
print(selected_trip.shape)
# Out:
# (397, 7)

# %%
selected_trip
# Out:
#       route_id  service_id  trip_id trip_headsign  block_id  direction_id  \
# 47813       10          52    33584   13th-Market      9062             0
# 47814       10          52    33585   13th-Market      9063             0
# 47815       10          52    33586   13th-Market      9062             0
# 47816       10          52    33587   13th-Market      9061             0
# 47817       10          52    33588   13th-Market      9051             0
# ...        ...         ...      ...           ...       ...           ...
# 49110       10          55    34639   40th-Market      9060             0
# 49111       10          55    34640   40th-Market      9058             0
# 49112       10          55    34641   40th-Market      9059             0
# 49113       10          55    34642   40th-Market      9060             0
# 49114       10          55    34643   40th-Market      9058             0
#
#        shape_id
# 47813    274383
# 47814    274383
# 47815    274383
# 47816    274383
# 47817    274383
# ...         ...
# 49110    274385
# 49111    274385
# 49112    274385
# 49113    274385
# 49114    274385
#
# [397 rows x 7 columns]

# %% [markdown]
# Get a bus trip information of route 10

# %%
a_bus_trip = selected_trip.iloc[2]
a_bus_trip
# Out:
# route_id                  10
# service_id                52
# trip_id                33586
# trip_headsign    13th-Market
# block_id                9062
# direction_id               0
# shape_id              274383
# Name: 47815, dtype: object

# %% [markdown]
# #### Get the stop time information

# %%
stop_times_file = bus_dir_path + "/stop_times.txt"

stop_times_df = pd.read_csv(stop_times_file)
stop_times_df
# Out:
#          trip_id arrival_time departure_time  stop_id  stop_sequence
# 0          33584     07:14:00       07:14:00    31294              1
# 1          33584     07:14:00       07:14:00    20610              2
# 2          33584     07:15:00       07:15:00    20611              3
# 3          33584     07:16:00       07:16:00    20612              4
# 4          33584     07:18:00       07:18:00    20613              5
# ...          ...          ...            ...      ...            ...
# 3007413    89980     15:17:00       15:17:00    23718             53
# 3007414    89980     15:17:00       15:17:00    23633             54
# 3007415    89980     15:18:00       15:18:00    22402             55
# 3007416    89980     15:19:00       15:19:00    31356             56
# 3007417    89980     15:20:00       15:20:00     1117             57
#
# [3007418 rows x 5 columns]

# %%
## Let's extract the rows from stop_times dataframe that correspond to this particular trip.
a_bus_trip_stop_times = stop_times_df.loc[stop_times_df.trip_id == a_bus_trip.trip_id]

# print(a_bus_trip_stop_times.iloc[0].arrival_time)
a_bus_trip_stop_times.head()
# Out:
#     trip_id arrival_time departure_time  stop_id  stop_sequence
# 72    33586     08:37:00       08:37:00    31294              1
# 73    33586     08:37:00       08:37:00    20610              2
# 74    33586     08:38:00       08:38:00    20611              3
# 75    33586     08:39:00       08:39:00    20612              4
# 76    33586     08:41:00       08:41:00    20613              5

# %% [markdown]
# #### Get the stops location information
# Now that we've arrival, departure times of this trip, we need to figure out the names of the stops along the way. Stops for this particular trip are in the stop_id of this data. The stop names are stored in stops.txt. Let's load that file.

# %%
stops_txt = bus_dir_path + "/stops.txt"

stops_df = pd.read_csv(stops_txt)
stops_df.head()
# Out:
#    stop_id                               stop_name   stop_lat   stop_lon  \
# 0        2  Ridge Av & Wissahickon Transfer Center  40.014986 -75.206826
# 1        4          Roosevelt Blvd & Broad St - FS  40.018128 -75.148887
# 2        5                 Roosevelt Blvd & 5th St  40.023465 -75.133487
# 3        7               Roosevelt Blvd & Pratt St  40.028754 -75.089524
# 4        8        Roosevelt Blvd & Cottman Av - FS  40.044610 -75.053657
#
#    location_type  parent_station  zone_id  wheelchair_boarding
# 0            NaN         31032.0        1                    1
# 1            NaN             NaN        1                    1
# 2            NaN             NaN        1                    1
# 3            NaN             NaN        1                    1
# 4            NaN             NaN        1                    1

# %% [markdown]
# Let's examine the detailed information of our selected trip for route 10

# %%
stops = stops_df[stops_df.stop_id.isin(a_bus_trip_stop_times.stop_id)]

stops.head()
# Out:
#       stop_id                 stop_name   stop_lat   stop_lon  location_type  \
# 157       277  Lancaster Av & Girard Av  39.973059 -75.218615            NaN
# 159       283   13th St Trolley Station  39.952532 -75.162559            NaN
# 2007    15271    Lansdowne Av & 60th St  39.975851 -75.240378            NaN
# 5839    20610      Malvern Av & 63rd St  39.983697 -75.247009            NaN
# 5840    20611      63rd St & Lebanon Av  39.980912 -75.246661            NaN
#
#       parent_station  zone_id  wheelchair_boarding
# 157              NaN        1                    2
# 159              NaN        1                    2
# 2007             NaN        1                    2
# 5839             NaN        1                    2
# 5840             NaN        1                    2

# %% [markdown]
# #### We can only get the coordinate info of those bus stops

# %%
stop_names = stops_df[['stop_id','stop_name', 'stop_lat', 'stop_lon']]

# %%
stop_names.head()
# Out:
#    stop_id                               stop_name   stop_lat   stop_lon
# 0        2  Ridge Av & Wissahickon Transfer Center  40.014986 -75.206826
# 1        4          Roosevelt Blvd & Broad St - FS  40.018128 -75.148887
# 2        5                 Roosevelt Blvd & 5th St  40.023465 -75.133487
# 3        7               Roosevelt Blvd & Pratt St  40.028754 -75.089524
# 4        8        Roosevelt Blvd & Cottman Av - FS  40.044610 -75.053657

# %% [markdown]
# So now we have the stop_ids, and arrival/departure time in one data frame, and the stop_ids, and stop_names in another. Let's combine them to get comprehensive information about the schedule for this particular trip.

# %%
a_bus_trip_stop_times.merge(stop_names, on='stop_id')
# Out:
#     trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0     33586     08:37:00       08:37:00    31294              1
# 1     33586     08:37:00       08:37:00    20610              2
# 2     33586     08:38:00       08:38:00    20611              3
# 3     33586     08:39:00       08:39:00    20612              4
# 4     33586     08:41:00       08:41:00    20613              5
# 5     33586     08:41:00       08:41:00    20614              6
# 6     33586     08:42:00       08:42:00    20615              7
# 7     33586     08:43:00       08:43:00    15271              8
# 8     33586     08:43:00       08:43:00    20616              9
# 9     33586     08:44:00       08:44:00    20617             10
# 10    33586     08:44:00       08:44:00    20618             11
# 11    33586     08:45:00       08:45:00    20619             12
# 12    33586     08:45:00       08:45:00    20622             13
# 13    33586     08:46:00       08:46:00    20623             14
# 14    33586     08:47:00       08:47:00    20624             16
# 15    33586     08:47:00       08:47:00    20625             17
# 16    33586     08:49:00       08:49:00    20626             18
# 17    33586     08:50:00       08:50:00    20627             19
# 18    33586     08:51:00       08:51:00      277             20
# 19    33586     08:52:00       08:52:00    20628             21
# 20    33586     08:53:00       08:53:00    20630             22
# 21    33586     08:54:00       08:54:00    20631             23
# 22    33586     08:54:00       08:54:00    20632             24
# 23    33586     08:55:00       08:55:00    20633             25
# 24    33586     08:56:00       08:56:00    20634             26
# 25    33586     08:58:00       08:58:00    20635             27
# 26    33586     08:59:00       08:59:00    20636             29
# 27    33586     09:00:00       09:00:00    20638             30
# 28    33586     09:02:00       09:02:00    20639             31
# 29    33586     09:04:00       09:04:00    20641             34
# 30    33586     09:05:00       09:05:00    20642             36
# 31    33586     09:06:00       09:06:00    20643             37
# 32    33586     09:08:00       09:08:00    20645             38
# 33    33586     09:09:00       09:09:00    20646             39
# 34    33586     09:10:00       09:10:00    31140             40
# 35    33586     09:12:00       09:12:00      283             41
#
#                                stop_name   stop_lat   stop_lon
# 0   Malvern Av & 63rd St Loop - 2 onsite  39.983838 -75.245957
# 1                   Malvern Av & 63rd St  39.983697 -75.247009
# 2                   63rd St & Lebanon Av  39.980912 -75.246661
# 3                 63rd St & Jefferson St  39.978350 -75.246184
# 4               Lansdowne Av & 63rd - FS  39.975332 -75.244986
# 5                 Lansdowne Av & 62nd St  39.975499 -75.243651
# 6                 Lansdowne Av & 61st St  39.975693 -75.241879
# 7                 Lansdowne Av & 60th St  39.975851 -75.240378
# 8                 Lansdowne Av & 59th St  39.976054 -75.238653
# 9                 Lansdowne Av & 58th St  39.976248 -75.236904
# 10                Lansdowne Av & 57th St  39.976406 -75.235403
# 11                Lansdowne Av & 56th St  39.976591 -75.233761
# 12                Lansdowne Av & 55th St  39.976811 -75.231858
# 13                Lansdowne Av & 54th St  39.977013 -75.229908
# 14           Lansdowne Av & Lancaster Av  39.977295 -75.227451
# 15              Lancaster Av & Bible Way  39.976855 -75.226176
# 16                Lancaster Av & 50th St  39.975207 -75.222590
# 17            Lancaster Av & Thompson St  39.973748 -75.219747
# 18              Lancaster Av & Girard Av  39.973059 -75.218615
# 19                Lancaster Av & 47th St  39.971555 -75.216115
# 20                Lancaster Av & 45th St  39.969667 -75.212991
# 21                Lancaster Av & 44th St  39.968772 -75.211541
# 22                Lancaster Av & 43th St  39.967725 -75.209878
# 23                Lancaster Av & 42nd St  39.966391 -75.207662
# 24                Lancaster Av & 41st St  39.965093 -75.205564
# 25                Lancaster Av & 40th St  39.963151 -75.202440
# 26       Lancaster Av & Spring Garden St  39.962004 -75.200353
# 27                Lancaster Av & 38th St  39.960267 -75.197016
# 28                Lancaster Av & 36th St  39.958565 -75.193786
# 29        36th St Trolley Portal Station  39.955335 -75.194162
# 30               33rd St Trolley Station  39.954773 -75.189700
# 31               30th St Trolley Station  39.954815 -75.183500
# 32               22nd St Trolley Station  39.953962 -75.176736
# 33               19th St Trolley Station  39.953327 -75.171637
# 34               15th St Trolley Station  39.952502 -75.165369
# 35               13th St Trolley Station  39.952532 -75.162559

# %% [markdown]
# Voila! There we have it! The schedule for Bus stop of 10.
